# %% [markdown]
# <a href="https://colab.research.google.com/github/manipriyasaravanan30-spec/Project-/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array ([90, 85, 78, 92])

print(marks [2])
# Out:
# 78
