# %% [markdown]
# <a href="https://colab.research.google.com/github/manipriyasaravanan30-spec/Project-/blob/main/Day_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {

'Name': ['John', 'Mary', 'David', 'Sam'],

'Sales': [1000, None, 1500, None]

}

df= pd.DataFrame(data)

print(df)
# Out:
#     Name   Sales
# 0   John  1000.0
# 1   Mary     NaN
# 2  David  1500.0
# 3    Sam     NaN
