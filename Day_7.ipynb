# %% [markdown]
# <a href="https://colab.research.google.com/github/manipriyasaravanan30-spec/Project-/blob/main/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

marks= [45, 58, 55, 60, 65, 70, 72, 75, 80, 85, 90, 95]

plt.hist(marks)

plt.title("Student Marks Distribution")

plt.xlabel("Marks")

plt.ylabel("Number of Students")

plt.show()
