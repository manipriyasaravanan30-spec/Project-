# %% [markdown]
# <a href="https://colab.research.google.com/github/manipriyasaravanan30-spec/Project-/blob/main/Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

employee = {

"ID": [101,102,103],

"Name": ["Arun", "Kumar", "Priya"],

"Salary": [50000,60000, 55000]

}

df = pd.DataFrame (employee)

print(df)
# Out:
#     ID   Name  Salary
# 0  101   Arun   50000
# 1  102  Kumar   60000
# 2  103  Priya   55000
